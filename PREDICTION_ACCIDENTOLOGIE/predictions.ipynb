# %% [markdown]
# # Prédiction des accidents de voitures en Île-de-France
#
# Application des techniques vues dans le cours d'analyse de séries temporelles openclassroom.
#
# Nous avons déjà vu le principe des séries temporelles. Un série temporelle est composée de :
# - d'une tendance,
# - d'une saisonnalité,
# - de résidus.
#
# Dans un premier temps, il est nécessaire de "retirer" la saisonnalité présente dans nos données. En effet, afin de comparer deux instants successifs, il est nécessaire de retirer la saisonnalité. On parlera alors de "séries corrigées des variations saisonnières". Deux méthodes sont possibles :
# - la régression linéaire,
# - les moyennes mobiles.

# %%
import pandas
import numpy
import matplotlib.pyplot as plt
import seaborn

from statsmodels.tsa.seasonal import seasonal_decompose

# %%
acc = pandas.read_csv(".\\TRAITEMENT\\accidents_par_jour_en_idf.csv", sep=";", decimal=",")
acc.head()
# Out:
#     date_cplt date_cplt.1  nb_acc
# 0  2021-01-01  2021-01-01       6
# 1  2021-10-01  2021-10-01      35
# 2  2021-11-01  2021-11-01      15
# 3  2021-12-01  2021-12-01      40
# 4  2021-02-01  2021-02-01      18

# %% [markdown]
# ## 1/Désaisonnaliser la série
#
# ### 1.1/Avec la régression linéaire

# %% [markdown]
# ###  1.2/Avec les moyennes mobiles

# %% [markdown]
# Pour pouvoir "définir" une période, la recherche est visuelle :

# %%
fig, ax = plt.subplots(figsize=(25, 4))

ax.plot(acc["date_cplt"], acc["nb_acc"])

ax.set_title("Evolution du nombre d'accidents de voitures et de moto en Île-de-France en 2021")

plt.show()
